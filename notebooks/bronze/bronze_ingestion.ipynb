# %%
from src.finance_cockpits.common.reader import read_excel
from src.finance_cockpits.common.writer import write_data
from pyspark.sql.functions import *

# %%
# read excel

file_path="/Volumes/cockpit/finance/invoice_raw/Invoice.xlsx"
sheet_name="Invoice"

df=read_excel(spark,file_path,sheet_name)
display(df)

# %%
df_new=(df.withColumnRenamed("Amount (INR)","Amount")
        .withColumnRenamed("Rate (INR)","Rate"))
display(df_new)

# %%
# write data to silver table
write_data(df_new,"cockpit.finance.bronze_table")
