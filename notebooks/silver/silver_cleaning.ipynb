# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
from src.finance_cockpits.common.writer import write_data
from src.finance_cockpits.common.reader import read_delta_table

# %%
df_bronze=read_delta_table(spark,"cockpit.finance.silver_table")
display(df_bronze)

# %%
df_bronze=df_bronze.sort("Hours",ascending=False).limit(5)

# %%
write_data(df_bronze,"cockpit.finance.silver_table")
